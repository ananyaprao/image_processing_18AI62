# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img=Image.open(r"C:\Users\SAHYADRI\Pictures\Saved Pictures\390730-sepik.jpg")
img1=np.array(img)
print(img1.shape)
plt.figure()
plt.imshow(img1)

img=Image.open(r"C:\Users\SAHYADRI\Pictures\Saved Pictures\419830-Kycb.jpg")
img2=np.array(img)
print(img2.shape)
plt.figure()
plt.imshow(img2)

img=img1//2+img2//2
plt.figure()
plt.imshow(img)
# Out:
# (833, 1280, 3)
# (833, 1280, 3)
