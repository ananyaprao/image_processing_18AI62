# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyaprao/image_processing_18AI62/blob/main/4SF20CI010_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import cv2

# %% [markdown]
# READING THE IMAGE

# %%
img = cv2.imread("/content/th.jpg")

# %% [markdown]
# DISPLAYING THE ORIGINAL IMAGE

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=474x409 at 0x7F149F4FC7D0>

# %% [markdown]
# CONVERTING TO MATRIX

# %%
print(img)
# Out:
# [[[ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]
#   ...
#   [ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]]
#
#  [[ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]
#   ...
#   [ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]]
#
#  [[ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]
#   ...
#   [ 2  1  3]
#   [ 2  1  3]
#   [ 2  1  3]]
#
#  ...
#
#  [[18 18 18]
#   [ 1  1  1]
#   [ 0  0  0]
#   ...
#   [ 0 10  4]
#   [ 0  6  3]
#   [ 4 13 10]]
#
#  [[44 44 44]
#   [20 20 20]
#   [ 3  3  3]
#   ...
#   [ 0 10  4]
#   [22 31 28]
#   [33 42 39]]
#
#  [[59 59 59]
#   [ 2  2  2]
#   [ 0  0  0]
#   ...
#   [ 0 11  5]
#   [ 0  9  6]
#   [56 65 62]]]

# %% [markdown]
# CONVERTING TO GREY SCALE

# %%
img_gray=cv2.imread("/content/th.jpg",0)

# %% [markdown]
# DISPLAYNG GRAYSCALE IMAGE

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=474x409 at 0x7F149F483B90>

# %% [markdown]
# CONVERTING GRAYSCALE TO MATRIX

# %%
print(img_gray)
# Out:
# [[ 2  2  2 ...  2  2  2]
#  [ 2  2  2 ...  2  2  2]
#  [ 2  2  2 ...  2  2  2]
#  ...
#  [18  1  0 ...  7  4 11]
#  [44 20  3 ...  7 29 40]
#  [59  2  0 ...  8  7 63]]
